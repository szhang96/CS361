# %%
import matplotlib.pyplot as plt
import math
import numpy

x = numpy.linspace(0,2,50)
y = numpy.sin(x-2)**2 * e ** -x ** 2
plt.plot(x,y)
plt.ylabel('sin^2(x-2)e^-x^2')
plt.xlabel('x values from 0 to 2')
plt.title('f(x) = sin^2(x-2)e^-x^2')
plt.show()
